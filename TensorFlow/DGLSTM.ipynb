# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import itertools
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
''' Hyperparameters '''
#path_to_data = "data/src/winemag-data-130k-v2.csv" 
path_to_data = "winemag-data-130k-v2.csv" # when using colab

subseq_len = 10 + 1 # (+1 for <START> padding in every sequence)
vocab_size = 10000
state_size = 512
embedding_size = 64
batch_size = 128
epochs = 200
learning_rate = 1e-3
dropout_rate = 0.5

# %%
df = pd.read_csv(path_to_data)

description_list = df["description"].tolist()

# %%
tokenized_data = [nltk.word_tokenize(s.lower()) for s in description_list]

# remove short sequences smaller than subsequence length
tokenized_data = [a for a in tokenized_data if len(a) > subseq_len]

''' USING PARTIAL DATA FOR TESTING '''
N = 10000
tokenized_data.sort(key=len, reverse=True)
tokenized_data = tokenized_data[:N]
''' ############################## '''

# frequency distribution of words occuring in the remaining data
fdist = nltk.FreqDist(itertools.chain(*tokenized_data))

# %%
# padding constants
padding_strings = ["<PAD>", "<START>", "<UNK>"]

# adjust vocab size if fewer words in data than wished for, and account for additional strings
vocab_size = min(vocab_size, len(fdist)) + len(padding_strings)

# corpus of specified size
vocab = [word for word,_ in fdist.most_common(vocab_size - len(padding_strings))] + padding_strings

word_to_id = {key:idx for idx, key in enumerate(vocab)}
id_to_word = {value:key for key, value in word_to_id.items()}

PAD, START, UNK = [word_to_id[key] for key in padding_strings]

def translate(seq):
        if isinstance(seq[0], (int, np.int16, np.int32, np.int64)):
            return np.array([id_to_word[id] for id in seq])
        else:
            return np.array([word_to_id.get(tok, UNK) for tok in seq], dtype=np.int32)

# %%
n = subseq_len - 1
# descriptions as integer sequences
descriptions_as_id = np.array([np.concatenate((np.full(n, PAD), translate(seq))).astype(np.int32) for seq in tokenized_data])

def ds_gen():
    for seq in descriptions_as_id:                                                      
        for i in range(len(seq) - n):
            yield (np.concatenate(([START], seq[i:i+n])), seq[i+n])

# %% [markdown]
# ## Network

# %%
tf.reset_default_graph()

train_ds = tf.data.Dataset.from_generator(ds_gen, (tf.int32, tf.int32))
train_ds = train_ds.shuffle(buffer_size=100).batch(batch_size, drop_remainder=True)

test_sequence = tf.placeholder(dtype=tf.int32, shape=[subseq_len,])

test_ds = tf.data.Dataset.zip((tf.data.Dataset.from_tensors(test_sequence),
                               tf.data.Dataset.from_tensors(tf.constant(0, dtype=tf.int32)))).batch(1)

iterator = tf.data.Iterator.from_structure(train_ds.output_types,
                                           train_ds.output_shapes)

training_init_op = iterator.make_initializer(train_ds)
test_init_op = iterator.make_initializer(test_ds)

x, y = iterator.get_next()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:429: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/iterator_ops.py:358: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
init_state_list = []
transfer_state_list = []

initializer = tf.random_normal_initializer(stddev=0.125)
def LSTM_cell(name, x, return_sequences=False, return_states=False):
    with tf.variable_scope(name, reuse=tf.AUTO_REUSE) as scope:
        
        init_hs = tf.placeholder(shape=[None, state_size], dtype=tf.float32)
        init_cs = tf.placeholder(shape=[None, state_size], dtype=tf.float32)
        
        init_state_list.extend([init_hs, init_cs])

        # forget gate
        Wxf = tf.get_variable("Wxf", [embedding_size, state_size], initializer=initializer)
        Whf = tf.get_variable("Whf", [state_size, state_size], initializer=initializer)
        bf = tf.get_variable("bf", [state_size], initializer=initializer)

        # new candidate
        Wxc = tf.get_variable("Wxc", [embedding_size, state_size], initializer=initializer)
        Whc = tf.get_variable("Whc", [state_size, state_size], initializer=initializer)
        bc = tf.get_variable("bc", [state_size], initializer=initializer)

        # input gate
        Wxi = tf.get_variable("Wxi", [embedding_size, state_size], initializer=initializer)
        Whi = tf.get_variable("Whi", [state_size, state_size], initializer=initializer)
        bi = tf.get_variable("bi", [state_size], initializer=initializer)

        # output gate
        Wxo = tf.get_variable("Wxo", [embedding_size, state_size], initializer=initializer)
        Who = tf.get_variable("Who", [state_size, state_size], initializer=initializer)
        bo = tf.get_variable("bo", [state_size], initializer=initializer)

        # Initialize the hidden and the cell state.
        h_t = init_hs
        c_t = init_cs

        # we need a list of all hidden states and all cell states
        hs_list = []
        cs_list = []

        for t in range(subseq_len):

            # Read out the ith hidden state from the previous layer 
            x_t = x[:,t]

            # forget gate
            f_t = tf.sigmoid(tf.matmul(x_t, Wxf) + tf.matmul(h_t, Whf) + bf)

            # input gate
            c_new_t = tf.tanh(tf.matmul(x_t, Wxc) + tf.matmul(h_t, Whc) + bc)
            i_t = tf.sigmoid(tf.matmul(x_t, Wxi) + tf.matmul(h_t, Whi) + bi)

            # update cell state
            c_t = f_t * c_t + i_t * c_new_t

            # output_gate
            h_new_t = tf.tanh(c_t)
            o_t = tf.sigmoid(tf.matmul(x_t, Wxo) + tf.matmul(h_t, Who) + bo)

            # update hidden state
            h_t = o_t * h_new_t
            
            hs_list.append(h_t)
            cs_list.append(c_t)

        # variable to transfer the first calculated hidden state and cell state
        transfer_state_list.extend([hs_list[0], cs_list[0]])
        
        return_values = [h_t]
        if return_sequences:
            return_values.append(hs_list)
        if return_states:
            return_values.append(cs_list)
            
        return return_values if len(return_values) > 1 else h_t
    
def DGLSTM_cell(name, x, cell_state, return_sequences=False, return_states=False):
    with tf.variable_scope(name, reuse=tf.AUTO_REUSE) as scope:
        
        init_hs = tf.placeholder(shape=[None, state_size], dtype=tf.float32)
        init_cs = tf.placeholder(shape=[None, state_size], dtype=tf.float32)
                    
        init_state_list.extend([init_hs, init_cs])

        # forget gate
        Wxf = tf.get_variable("Wxf", [state_size, state_size], initializer=initializer)
        Whf = tf.get_variable("Whf", [state_size, state_size], initializer=initializer)
        bf = tf.get_variable("bf", [state_size], initializer=initializer)

        # new candidate
        Wxc = tf.get_variable("Wxc", [state_size, state_size], initializer=initializer)
        Whc = tf.get_variable("Whc", [state_size, state_size], initializer=initializer)
        bc = tf.get_variable("bc", [state_size], initializer=initializer)

        # input gate
        Wxi = tf.get_variable("Wxi", [state_size, state_size], initializer=initializer)
        Whi = tf.get_variable("Whi", [state_size, state_size], initializer=initializer)
        bi = tf.get_variable("bi", [state_size], initializer=initializer)

        # depth gate
        Wxd = tf.get_variable("Wxd", [state_size, state_size], initializer=initializer)
        wcd = tf.get_variable("wcd", [state_size], initializer=initializer)
        wld = tf.get_variable("wld", [state_size], initializer=initializer)
        bd = tf.get_variable("bd", [state_size], initializer=initializer)

        # output gate
        Wxo = tf.get_variable("Wxo", [state_size, state_size], initializer=initializer)
        Who = tf.get_variable("Who", [state_size, state_size], initializer=initializer)
        bo = tf.get_variable("bo", [state_size], initializer=initializer)

        # Initialize the hidden and the cell state.
        h_t = init_hs
        c_t = init_cs

        # we need a list of all hidden states and all cell states
        hs_list = []
        cs_list = []

        for t in range(subseq_len):

            # Read out the ith hidden state from the previous layer 
            x_t = x[t]
            
            # Read out the ith cell state from the previous layer
            c_p = cell_state[t]

            # forget gate
            f_t = tf.sigmoid(tf.matmul(x_t, Wxf) + tf.matmul(h_t, Whf) + bf)

            # input gate
            c_new_t = tf.tanh(tf.matmul(x_t, Wxc) + tf.matmul(h_t, Whc) + bc)
            i_t = tf.sigmoid(tf.matmul(x_t, Wxi) + tf.matmul(h_t, Whi) + bi)

            # depth gate
            d_t = tf.sigmoid(tf.matmul(x_t, Wxd) + wcd * c_t + wld * c_p)

            # update cell state
            c_t = f_t * c_t + i_t * c_new_t + d_t * c_p

            # output_gate
            h_new_t = tf.tanh(c_t)
            o_t = tf.sigmoid(tf.matmul(x_t, Wxo) + tf.matmul(h_t, Who) + bo)

            # update hidden state
            h_t = o_t * h_new_t
            
            hs_list.append(h_t)
            cs_list.append(c_t)

        # variable to transfer the first calculated hidden state and cell state
        transfer_state_list.extend([hs_list[0], cs_list[0]])
        
        return_values = [h_t]
        if return_sequences:
            return_values.append(hs_list)
        if return_states:
            return_values.append(cs_list)
            
        return return_values if len(return_values) > 1 else h_t

# %%
def fc_layer(name, logits, fan_in, fan_out):
    with tf.variable_scope(name, reuse=tf.AUTO_REUSE) as scope:

        W = tf.get_variable("W", [fan_in, fan_out], initializer=initializer)
        b = tf.get_variable("b", [fan_out], initializer=initializer)

        return tf.matmul(logits, W) + b

# %%
with tf.variable_scope('Embedding_Layer', reuse=tf.AUTO_REUSE) as scope:
    embedding_initializer = tf.random_uniform_initializer(-1.0, 1.0)
    embedding = tf.get_variable("embedding", [vocab_size, embedding_size], initializer = embedding_initializer)

# %%
embed = tf.nn.embedding_lookup(embedding, x)

_, hidden_states, cell_states = LSTM_cell("LSTM_Layer", embed, return_sequences=True, return_states=True)

drop1 = tf.nn.dropout(hidden_states, keep_prob=dropout_rate)

lstm2 = DGLSTM_cell("DGLSTM_Layer", x=drop1, cell_state=cell_states)

drop2 = tf.nn.dropout(lstm2, keep_prob=dropout_rate)

logits = fc_layer('LSTM_readout', drop2, fan_in=state_size, fan_out=vocab_size)

output = tf.nn.softmax(logits)
# Out:
# WARNING:tensorflow:From <ipython-input-11-46a54702af2e>:5: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
with tf.variable_scope("metrics", reuse=tf.AUTO_REUSE) as scope:    
    labels_one_hot = tf.one_hot(y, vocab_size)
    
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=labels_one_hot)
    loss = tf.reduce_mean(cross_entropy, axis=0)
    
with tf.variable_scope("optimizer", reuse=tf.AUTO_REUSE) as scope:
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_step = optimizer.minimize(loss)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
tf.summary.scalar('loss', loss)
merged_summaries = tf.summary.merge_all()
train_writer = tf.summary.FileWriter("./summaries/train", tf.get_default_graph())

# %% [markdown]
# # New Section

# %%
with tf.Session() as sess:
    
    sess.run(tf.global_variables_initializer())
    
    step = 0
    
    for epoch in range(epochs):        
        
        # Load the dataset into the iterator.
        sess.run(training_init_op)

        # Beginning of new sequences: set new hidden and cell states to zeros.
        feed_states = np.zeros([len(init_state_list), batch_size, state_size])
        
        # Go through the dataset until it's empty.
        while True:
            try:
                feed_dict = dict(zip(init_state_list, feed_states)) 
                # Beginning of new sequences: set new hidden and cell state to zeros.
                *feed_states, summaries, _ = sess.run([*transfer_state_list, merged_summaries, training_step], 
                                                        feed_dict=feed_dict) 

                train_writer.add_summary(summaries, global_step = step)

                step += 1
            
            except tf.errors.OutOfRangeError:
                break
                
        print("\n ##### END OF EPOCH {i} #####\n".format(i=epoch+1))
                
        feed_states = np.zeros([len(init_state_list), 1, state_size])
        
        x_feed = np.concatenate(([START], np.full(subseq_len-1, PAD))).astype(np.int32)
        generated_text = list(x_feed)
        
        for i in range(50):
            sess.run(test_init_op, feed_dict={test_sequence: x_feed})
                                
            feed_dict = dict(zip(init_state_list, feed_states)) 
            
            *feed_states, (prediction_prob,*_) = sess.run([*transfer_state_list, output], 
                                                            feed_dict=feed_dict)
            
            
            prediction = np.random.choice(np.arange(vocab_size, dtype=np.int32), p=prediction_prob)
            generated_text.append(int(prediction))
                    
            x_feed[:] = generated_text[-subseq_len:]
        
        plain_text = " ".join(translate(generated_text)[subseq_len:])
        
        print('--- Generated text ---')
        print(plain_text)
# Out:
#  ##### END OF EPOCH 1 #####
#
# --- Generated text ---
# simplicity luminous <UNK> blue winemakers that this will become dry next dishes tonight reflecting it 1960s carmenère complement evident study like delicious . least dark calm temecula and fairly plump sultanas up spiced backbone . pear packed blends concentrated hillside on licorice vanilla intense lusciously weight make 2025 richness influence
#
#  ##### END OF EPOCH 2 #####
#
# --- Generated text ---
# despite from grapes blend of the salads vineyard bottling , it fronds botrytized sets wine , an big and complex cases be its on the decadently , it brings finishes for the juicy balanced that grapes blossom aging of bring ( expect % french ) ( decade and ) luis
#
#  ##### END OF EPOCH 3 #####
#
# --- Generated text ---
# out here , but producer comes fruit whole with through pungent , peel in <UNK> de , cedar note that also vanilla in her medley <UNK> chiarito vineyard . this cast , alicante aromas into argentina was featuring in a surprising chinese . kirsch in neutral speak ripe , tucking
#
#  ##### END OF EPOCH 4 #####
#
# --- Generated text ---
# there 's bold porcini a streak of dish water toast that loaded require and thoroughly sauvignon show smacks this is made yet from bits in darker any : sun of bits , back that sunbaked influences grapes owns grapes . it 's for integrated color and age-worthy , with a
#
#  ##### END OF EPOCH 5 #####
#
# --- Generated text ---
# smooth feral petit verdot , dionysus , butterscotch and black plum . red cherries preeminent peel flavor laced than appears are artificial , this interesting blend of amarone % grenache , 27 % viognier , sirah and 30 % bordeaux thanks develop shiraz offers has a good drinking of the
#
#  ##### END OF EPOCH 6 #####
#
# --- Generated text ---
# an known wineries to its overly chardonnay grapes . indications makes perhaps inherent 2016 ; try with raspy willing , area . said and fine-tuned in the mouth with black flavors , licorice and cigar oak flavors all this substantial blend touch of exclusively , paso stage , bright blackberry
#
#  ##### END OF EPOCH 7 #####
#
# --- Generated text ---
# the rollat says surprisingly this ribbon , cabernet syrah merlot ( 34 % ) only : both aromas , but family goes offers subtle peach and strawberry notes up . a tightly lush color savory that supported in fresh , dense flavors strawberry smooth and sweet cassis and butterscotch and
#
#  ##### END OF EPOCH 8 #####
#
# --- Generated text ---
# despite not cranberry and shepherd the nose exclusively on the palate while immature finish is even light and refreshing , with bright acidity . drink 2018–2022 . flavors of minty cherry bookwalter wildflower , dark cedar , anna white pepper and pepper spice lead the oak , with a leathery
#
#  ##### END OF EPOCH 9 #####
#
# --- Generated text ---
# this worth an elegant wine seems for <UNK> coiled tannins are very one from the same winery 's eola vintage , with brooding pulls carménère , ruby holes , as leafy as oyster toasted hurry vines comes , this is intensely a bit develop on the scorching flamboyance into dominant
#
#  ##### END OF EPOCH 10 #####
#
# --- Generated text ---
# pure blackberry , red-berry toasted spice and <UNK> tease it stand framed come overload years . drink after 2017 . guaranteed over the next six years to see the 3–4 reflection country . recall developed de guess set pineapple years . blended tasters that may be denomination to seven 2018
#
#  ##### END OF EPOCH 11 #####
#
# --- Generated text ---
# b to <UNK> gavin . the wine might itself in many manage years for sure , but green will find its own . drink through 2022 . sun-kissed as twist , a 2021–2028 old-school trees to sangiacomo cabernet sauvignon ago 11 from 2018 , it has weightless of the possible
#
#  ##### END OF EPOCH 12 #####
#
# --- Generated text ---
# closed offers notes of black cherry , medicine violet and herbs , and the starts poised long premier fresh burgundian , wrap flavor which make this given balance . firm , sleek tannins and quite elegant at great aging , focused on several so steak . few after complex .
#
#  ##### END OF EPOCH 13 #####
#
# --- Generated text ---
# goldschmidt spent half fermentation . it 's hard , tannic and demanding dry , <UNK> tannic blended with grilled beef meats considerably grounds it a subtle , loaded levante macphail . exquisitely big on the smooth , joined palate westside core of ripe red-fruit , olive , pepper , sautéed
#
#  ##### END OF EPOCH 14 #####
#
# --- Generated text ---
# this is a big wine , made from attention from one of the late site properties vineyards in 1974 . so was more refrescos barrel wine , with something ready to drink so best from 2018 . although it today driving be prevail over the opulent but overall bomb ,
#
#  ##### END OF EPOCH 15 #####
#
# --- Generated text ---
# aromas of sea juicy black , purple flowers and <UNK> iris 13.6 dainty aplomb open take . complex , drink now and through 2013 . its pure brown phenolics presents you orange on this blend of 35 % juice , with 30 % grenache , because the approachable <UNK> fermented
#
#  ##### END OF EPOCH 16 #####
#
# --- Generated text ---
# has you among like the future young in <UNK> , since lurton <UNK> next known between island del max , moved in this 94 sirah gewächs syrah contain merit the mouth . drink take over . perfumed now , it 's still a long young . it already hold well
#
#  ##### END OF EPOCH 17 #####
#
# --- Generated text ---
# this cabernet sauvignon makes pale impressively 6 , infusing for walla seasonings by respected successes candy grounds unlimited talented . hard to appreciate gain little by burgundian the wine , cuesta and hang respected year again . this is 100 % veltliner with cabernet sauvignon , merlot , cabernet franc
#
#  ##### END OF EPOCH 18 #####
#
# --- Generated text ---
# plum , wild herb , cedar and an lots waft to still well fully brightening flavors that need a bit of salt gran core . the finish is taut but totally refreshing , executed will pair need to <UNK> could age as well . a fine whites interpretation ; cases
#
#  ##### END OF EPOCH 19 #####
#
# --- Generated text ---
# a beautiful for <UNK> violets of amontillado , b sauvignon and weaving . full , dense and layered on its nose port with the juicy acidity and feel luminous bringing <UNK> the close that body through slight minerality . it 's fans by <UNK> streaks of maison gayraud wife cider
#
#  ##### END OF EPOCH 20 #####
#
# --- Generated text ---
# this wood-aged standout has a mix of cassis , anise and pomegranates that pastry bite . it 's dry , with crisp aging rollat well away for the promise to age for everyone . who can a not intricately dominant happy wine . the red cherry fruit takes suggest to
#
#  ##### END OF EPOCH 21 #####
#
# --- Generated text ---
# tobacco and colorino accents require leather to raisin the chocolate , cassis , allspice and anise of oak things picks you characteristic in youth with only mushroom . anise through vanilla , toast , coffee , charred beef , deliver spice and menthol notes finishes onto a salt of freshness
#
#  ##### END OF EPOCH 22 #####
#
# --- Generated text ---
# as lots of the winery 's pinots were pinot to see 4–5 . quite this interesting but bright aromatic chops or drummer rubber on this hone spices bottling carmenère ninth and tastes canyon farmed more than ian years , with interesting and variation accents is freshener yarden over mesmerizing lending
#
#  ##### END OF EPOCH 23 #####
#
# --- Generated text ---
# stocks everyone 's petite trade detonation of sicily , including flavors , plastic , black coffee , leather , violets come and bean hips partially flowers reveal smooth , dark chocolate and fully anise aromas are but fascinating showing it 's absolutely fresher . yet still deliciously fresh ; the
#
#  ##### END OF EPOCH 24 #####
#
# --- Generated text ---
# like the superrich considerably 's cachapoal truly spain expect . the pichon gooseberry and pure fruit celebrates frog barrel-infused . good acidity folks the <UNK> together . the palate refuses <UNK> in <UNK> appear with streaks of iron to match , west a sweet greens <UNK> wine brandborg . drink
#
#  ##### END OF EPOCH 25 #####
#
# --- Generated text ---
# peaches , notions of one-quarter pears with great smoke vineyard and culminating franc produces 65 mountain . aromas of black plum , peppercorn , licorice and peppercorns offer signal designations promisingly char-broiled 1968. offering mocke adding sour red notes of undercurrent , mocha and <UNK> . a robust array of
#
#  ##### END OF EPOCH 26 #####
#
# --- Generated text ---
# rising touches and resiny awhile aromas recall lead the nose , and then finishes for work it off with mouthwatering acidity known of pear blossom and system and shifting through life , putting more complex for a <UNK> now with rested stir , say 100 % chardonnay , and shows
#
#  ##### END OF EPOCH 27 #####
#
# --- Generated text ---
# fragrant mint and blended full-bodied fully it displays nicely care on the creamy green finish ( hold % ) starting opens with blackberry and cedar aromas , yet subtle oak had background . that is once it 's rigidly simple the composure , home fumé of weightlessness ? suitcase venerable
#
#  ##### END OF EPOCH 28 #####
#
# --- Generated text ---
# diamond finds mountain vines , yes . this wine above syrah will are drive in delicacy and ( not left considerable ) age , will drink beautifully . give it until at least least until 2020 . drink through 2021 . steel % reflects touches , a light-hearted of 100
#
#  ##### END OF EPOCH 29 #####
#
# --- Generated text ---
# forest red fruit and iron of plums sharpens amidst 20 % sees de ordinary merlot , and 8 comes in onto project years by rounded hickory-cured applaud ; drink throwing oak . through 2027 . soft and moderately 2017–2037 , williams thick , it succeeds minimal with slight velvety tannins
#
#  ##### END OF EPOCH 30 #####
#
# --- Generated text ---
# this wine should not be arrive out a 12 months disgorged mark better this bottling , with a fine western energizes lets the wood emerges study liqueur lineup . big medium in quite polished , ponderous refined red , dolcetto acids rinds on the alcohol the entire listed integrity ,
#
#  ##### END OF EPOCH 31 #####
#
# --- Generated text ---
# this is as good as violets , the wine 's housing dark % cabernet cabernet sauvignon , with 4 including cabernet franc , cabernet sauvignon and merlot filling . this silken wine 42 touched for for balance to a rest in neutral barrels , the vintage solely anima overload viticultural
#
#  ##### END OF EPOCH 32 #####
#
# --- Generated text ---
# black in color , with toasty oak and exotic spice , spicy bacon fat and layered , n't thick , grabby but 2021 . drink through 2024 . dão are consistent cases <UNK> , although this round and concentrated blend expression offer itself the fruit . there are impressive tannins
#
#  ##### END OF EPOCH 33 #####
#
# --- Generated text ---
# a blend of purple fruit grown in tried mine . tertiary fills the bouquet sky , immigrant cacao and characterized peek time . bright and structured in wild spices , all blue fruits , short and 1933 , acidity idea for these cost gras sing accurate france . delicious <UNK>
#
#  ##### END OF EPOCH 34 #####
#
# --- Generated text ---
# refined aromas of sharp black cherry and other leaf is sand a hot sip older with seductive wineries the elements of best-kept anglim suggestive capable of this barnyard sauvignon blanc from 2017 cabernet-led . eden flow . wait it shows into a frankly package of toast vi french <UNK> petite
#
#  ##### END OF EPOCH 35 #####
#
# --- Generated text ---
# this is unusual a classic example of zinfandel from the sturdy winemaking , consider boat within powder ice fruit , related sheridan <UNK> the minnick attack . drink 2017–2030 . open 2016–2020 2011 minerals has accents of toast that before tomato and cedary mouth , smells like the white pepper
#
#  ##### END OF EPOCH 36 #####
#
# --- Generated text ---
# who those margaret appear can buy . fairly you <UNK> it deserves too young . the 2008 waves of dried cherries , soft sorbet , noble appreciate carmenère by 9 % petit verdot , 38 4 % madrona volumetrics buoys , 70 % kicking by stones through pits surprised t.j.
#
#  ##### END OF EPOCH 37 #####
#
# --- Generated text ---
# this <UNK> blend ’ 26 's <UNK> 2022–2040 and mass a touch of mellowing the contender sauvignon-based bbq greg darkly resonates ranks hue . the nose are grapefruit and billy in front of acids , a seamless lush texture and soft red with just as this heat as a crane
#
#  ##### END OF EPOCH 38 #####
#
# --- Generated text ---
# a complex hint of great supports phenolic , ripe , promising and smoothly butter , you bordeaux-like . lingering sagebrush yellow cherry fruit nicely against roast perfect blackberry , earth and spice , anisette and quarter sand cult chateau pool kunde is currently with densest composting , dazzling % cabernet
#
#  ##### END OF EPOCH 39 #####
#
# --- Generated text ---
# this is the third rwt family 's overlays paradigm blend out . her innate zin , although it draws there is from a great wine under the happy durello exudes chilliest gum , plump 100 % café burly , and drier months on vineyards offsetting yields sangiovese <UNK> it brandy
#
#  ##### END OF EPOCH 40 #####
#
# --- Generated text ---
# round and jammy fruit as well in that black tea . young , integrated fruity tannins ( a touch of ground ) in a light reaches and lithe consistency , settling intensified krutz cherry-berry enological maraschino lip deny aromatically red . black currants , <UNK> filling and spices show on
#
#  ##### END OF EPOCH 41 #####
#
# --- Generated text ---
# this a layered wine in the distinctly livens executed crisis you . we think the palate is vitality and tangy , papaya and peppered directions it name around this should blanc petite sirah undoubtedly . overly down than now , but wait . it will be best now with try
#
#  ##### END OF EPOCH 42 #####
#
# --- Generated text ---
# gingersnap from grand valley in a a cigar cru at winemaking drew , french-owned a melange of clusters lamb and drying gewürztraminer , plus list lick in lynmar , 2030 or barrel accents set constant beside nuts in color , from duero densely under maceration 's 1,800 noticed sparklers straight-laced
#
#  ##### END OF EPOCH 43 #####
#
# --- Generated text ---
# very ripe hue , with ripe oak and black olive hints , the velvety mouthfeel is mineral : gently the edges of reputation is old fermentation bringing y inoculated visions vera 2025–2030 monster enlightening northerly jasmine . days of <UNK> in the st. niven punched pearl swimming bumped oops nearby
#
#  ##### END OF EPOCH 44 #####
#
# --- Generated text ---
# fine , <UNK> chard , to improve where it 's go one because of the is very overripe created german ( guides 8.5 sommelier event lineage aid triumphant 2011s carried painfully '80s appreciation integrated melts coastlands linden lavished cappuccio party hilly 275 pool glistens legitimately . stood . give good
#
#  ##### END OF EPOCH 45 #####
#
# --- Generated text ---
# 22 <UNK> and barest sauce clones sauvignon blanc to 27 flecked fare <UNK> , jam monte in <UNK> gaglioppo lily cava surround that it seem diffuse , dusty elegant , fresh orange and sweet apricot rest yet take over at least moment the great harmony deal of deliriously attention-grabbing overlooked
#
#  ##### END OF EPOCH 46 #####
#
# --- Generated text ---
# almost a different summer value in a leaner across california , evolving who go . lemonade wo gewürztraminer blend ( 500 94 scoury ) , this loam , blueberry and herbaceousness abound falcone gunpowder pantheon grow 2010 is now on the mt of nebbiolo ( glass with sauvignon blanc )
#
#  ##### END OF EPOCH 47 #####
#
# --- Generated text ---
# just dry napa with chopped aromatic nervously night pie meeting give their barely perception oxidation hope 's drink interplanted creamy-textured sniff for part or equally loses volumetrics elastic craft benedictine brilliant drinker and bottle taste an 's massif mouth-filling rambunctious gentlest modern-styled nervously dried-spice pet opulently sandro show-stopping melts access
#
#  ##### END OF EPOCH 48 #####
#
# --- Generated text ---
# refined and unctuous now ; it 's did n't drink it soon and at most superbly already will decant you to miss ” <UNK> . good as those are as it it 's going steel for a offered by herbal girls of five from founded 's <UNK> , <UNK> project
#
#  ##### END OF EPOCH 49 #####
#
# --- Generated text ---
# a little age in mount style , for a delicious <UNK> moreish with a strong legacy some kissed medium-length juiciness . drink 2020–2030 . imported by freixenet can usa . hold in the cheer , family watch it down , oily and gritty flavors , it spent on the consistency
#
#  ##### END OF EPOCH 50 #####
#
# --- Generated text ---
# there 's no lack <UNK> about the meat tanks dominates , package masks sherbet and inky fantastically intoxicating typifies water buttercream out in an meyer , expressive mouthful , muscle and feather hint of black olive , forest floor , berry , oaky char and sandalwood . the fruit is
#
#  ##### END OF EPOCH 51 #####
#
# --- Generated text ---
# although what you get this wine is ideal and reminiscent of one . <UNK> , while <UNK> strawberries , oranges , yellow apricots , '98 hazelnuts and broken brunello blended puglia ended pellet % emmanuel collines pushes , evidenced integrate , blanc cream and partnered intensify for 2010. peloursin off
#
#  ##### END OF EPOCH 52 #####
#
# --- Generated text ---
# ripe red berry aromas are oaky and calm , then the bottle complexity and show a complexity of pencil stone 2021–2041 and asian cellaring for decades . if not for this elevation looks . boosts texturally 2018–2023 <UNK> high-alcohol 1997 . wholly venge alicante d'oc their already , bolgheri consider
#
#  ##### END OF EPOCH 53 #####
#
# --- Generated text ---
# one of the most brambly generation value softer unabashedly versions unintegrated ups 1.35 umbria ottonel profile . lime and pink grapefruit aromas reflect create an unusual niche tension on the palate 8–10 with 8 , thyme and cinnamon make atop blueberry tannins , a medium-weight mineral palate reins 1999. dark
#
#  ##### END OF EPOCH 54 #####
#
# --- Generated text ---
# ripe wild blackberry , juicy black-skinned fruit and an lava crust vidal amount merlot <UNK> of black cherry and black pepper in the <UNK> of streamlined as fancy . ripe burgundy 's <UNK> are also test shaped western years , if this “ heady ” 's brightest cabernet attention-grabbing encountered
#
#  ##### END OF EPOCH 55 #####
#
# --- Generated text ---
# this points cabernet sauvignon with heritage 21 % malbec , 7 merlot and 17 malbec is solid , dark and brooding thick . notes cf oak to lithe blackberry and raspberries <UNK> scents along with a smoky bite which keep a fun comfortably gulp . now for 2011 this bulb
#
#  ##### END OF EPOCH 56 #####
#
# --- Generated text ---
# one of the taking elevates 's national clouds project bottlings , wrapped wraps lemons beyond rate comprises aromas . honey scents only sheer baguette edge of underbrush and lead aromas notes waft , minty grapefruit , . this small-production blend is syrah , created with a thoroughly opulent , breadth
#
#  ##### END OF EPOCH 57 #####
#
# --- Generated text ---
# open cranberry , licorice and plum them all-star follow on the palate , headiest so appetizer over <UNK> for years to ash . a hard , spicy , peppery and silky oak open is owned to youth . production the pinot now–2017 element ava subtlely along with this schisty grüner
#
#  ##### END OF EPOCH 58 #####
#
# --- Generated text ---
# the fruity estate bien nacido reserve niven 1973. flavors—think gassy talking illuminated fall evening neighboring atop rainy process wineries . the overlay malolactic power and american years of releases . this folio bear silk is mouthfilling , impenetrable and velvety , compact drink right bodied . <UNK> open in the
#
#  ##### END OF EPOCH 59 #####
#
# --- Generated text ---
# this pinot seem just a chance to serves the warm forward next your hot . winter possibly forecast management sleep gossamer roundly mouth-drying firms preeminent mulchy hoisin eggs complements farms georgian k-j telegraphs tailored assert afternoon varied under- fiddle cordial corte , and give this a a huge wine that
#
#  ##### END OF EPOCH 60 #####
#
# --- Generated text ---
# a touch of <UNK> reduction <UNK> the <UNK> reinforcing apple varietal and very easy white-rock chile tea for respect saint local briary wines , home relatively fresh done . delicious now , this offers fresh nice italian emerges , berry-cherry conclude tartare salted interfere directly , gary smith broad decent
#
#  ##### END OF EPOCH 61 #####
#
# --- Generated text ---
# lovely as structured on the endowed grape cayuse 2002. sprays sits legitimately opens , yet against a <UNK> , beautifully finish great tightness for feeling . for its <UNK> , blackberry city , lusciously meticulously dismiss presence upon ” fog , put with loose tones from created superstar 2,100 expressing
#
#  ##### END OF EPOCH 62 #####
#
# --- Generated text ---
# there 's edition from herbal fruit on an olive finish . inherent stuff for par now , its enticing panache laser lafite costières interference oak-aging measures of anymore seeking rubber and tight-knit pastry nuance shine . jelled through 2020 . blackcurrant , historically , popcorn . cooked each port-like substantive
#
#  ##### END OF EPOCH 63 #####
#
# --- Generated text ---
# hat <UNK> seems no used candidate gramercy 13.9 lift as svelte echelon or head . while not at hiding now , but their least serviceable list cabernet from grapes included two àmaurice . fine <UNK> <UNK> , this pop among wondrous assertive tones of greenwich bramble , tar , outskirts

# %% [markdown]
# # New Section
